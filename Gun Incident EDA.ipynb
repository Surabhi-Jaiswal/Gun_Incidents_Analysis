# %%
import pandas as pd
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Guns incident Data.csv")

# %%
df
# Out:
#          S.No.  Year  Month        Date    Reason              Education  \
# 0            1  2017      1  06-01-2017   Suicide              Bachelors
# 1            2  2017      1  19-01-2017   Suicide           Some college
# 2            3  2017      1  01-01-2017   Suicide              Bachelors
# 3            4  2017      2  06-02-2017   Suicide              Bachelors
# 4            5  2017      2  09-02-2017   Suicide            High School
# ...        ...   ...    ...         ...       ...                    ...
# 100793  100794  2019     12  21-12-2019  Homicide            High School
# 100794  100795  2019     12  22-12-2019  Homicide            High School
# 100795  100796  2019     12  02-12-2019  Homicide            High School
# 100796  100797  2019     12  17-12-2019  Homicide  Less than High School
# 100797  100798  2019     10  25-10-2019  Homicide            High School
#
#            Sex   Age                    Race  Hispanic  Place of incident  \
# ...

# %%
df.head()
# Out:
#    S.No.  Year  Month        Date   Reason     Education     Sex   Age  \
# 0      1  2017      1  06-01-2017  Suicide     Bachelors    Male  35.0
# 1      2  2017      1  19-01-2017  Suicide  Some college  Female  22.0
# 2      3  2017      1  01-01-2017  Suicide     Bachelors    Male  61.0
# 3      4  2017      2  06-02-2017  Suicide     Bachelors    Male  65.0
# 4      5  2017      2  09-02-2017  Suicide   High School    Male  32.0
#
#                      Race  Hispanic Place of incident  Police involvement
# 0  Asian/Pacific Islander       100              Home                   0
# 1                   White       100            Street                   0
# 2                   White       100   Other specified                   0
# 3                   White       100              Home                   0
# 4                   White       100   Other specified                   0

# %%
df.tail()
# Out:
#          S.No.  Year  Month        Date    Reason              Education  \
# 100793  100794  2019     12  21-12-2019  Homicide            High School
# 100794  100795  2019     12  22-12-2019  Homicide            High School
# 100795  100796  2019     12  02-12-2019  Homicide            High School
# 100796  100797  2019     12  17-12-2019  Homicide  Less than High School
# 100797  100798  2019     10  25-10-2019  Homicide            High School
#
#          Sex   Age      Race  Hispanic  Place of incident  Police involvement
# 100793  Male  37.0     Black       100               Home                   0
# 100794  Male  20.0     Black       100             Street                   0
# 100795  Male  21.0     Black       100             Street                   0
# 100796  Male  23.0  Hispanic       260             Street                   0
# 100797  Male  44.0     Black       100  Other unspecified                   0

# %%
df.shape
# Out:
# (100798, 12)

# %%
df.isnull().sum()
# Out:
# S.No.                    0
# Year                     0
# Month                    0
# Date                     0
# Reason                   0
# Education             1422
# Sex                      0
# Age                     18
# Race                     0
# Hispanic                 0
# Place of incident     1384
# Police involvement       0
# dtype: int64

# %%
df['Education'].fillna('Unknown', inplace=True)
df['Place of incident'].fillna('Unknown', inplace=True)

# %%
df.isnull().sum()
# Out:
# S.No.                  0
# Year                   0
# Month                  0
# Date                   0
# Reason                 0
# Education              0
# Sex                    0
# Age                   18
# Race                   0
# Hispanic               0
# Place of incident      0
# Police involvement     0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# S.No.                 0
# Year                  0
# Month                 0
# Date                  0
# Reason                0
# Education             0
# Sex                   0
# Age                   0
# Race                  0
# Hispanic              0
# Place of incident     0
# Police involvement    0
# dtype: int64

# %%
df.describe()
# Out:
#                S.No.           Year          Month            Age  \
# count  100798.000000  100798.000000  100798.000000  100798.000000
# mean    50399.500000    2018.000357       6.567601      44.857269
# std     29098.020554       0.816278       3.405609      19.494456
# min         1.000000    2017.000000       1.000000       1.000000
# 25%     25200.250000    2017.000000       4.000000      28.000000
# 50%     50399.500000    2018.000000       7.000000      43.000000
# 75%     75598.750000    2019.000000       9.000000      59.000000
# max    100798.000000    2019.000000      12.000000     108.000000
#
#             Hispanic  Police involvement
# count  100798.000000       100798.000000
# mean      114.179607            0.013909
# std        61.595734            0.117114
# min       100.000000            0.000000
# 25%       100.000000            0.000000
# 50%       100.000000            0.000000
# 75%       100.000000            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100798 entries, 0 to 100797
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   S.No.               100798 non-null  int64
#  1   Year                100798 non-null  int64
#  2   Month               100798 non-null  int64
#  3   Date                100798 non-null  object
#  4   Reason              100798 non-null  object
#  5   Education           100798 non-null  object
#  6   Sex                 100798 non-null  object
#  7   Age                 100798 non-null  float64
#  8   Race                100798 non-null  object
#  9   Hispanic            100798 non-null  int64
#  10  Place of incident   100798 non-null  object
#  11  Police involvement  100798 non-null  int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 9.2+ MB

# %%
df.dtypes
# Out:
# S.No.                   int64
# Year                    int64
# Month                   int64
# Date                   object
# Reason                 object
# Education              object
# Sex                    object
# Age                   float64
# Race                   object
# Hispanic                int64
# Place of incident      object
# Police involvement      int64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Reason', data=df)
plt.title('Incident Reasons Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'].dropna(), bins=30, kde=True)
plt.title('Age Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Race', data=df)
plt.title('Race Distribution')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Sex', data=df)
plt.title('Sex Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Reason', hue='Sex', data=df)
plt.title('Reason vs Sex')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Reason', y='Age', data=df)
plt.title('Age Distribution across Reasons')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Place of incident', hue='Reason', data=df)
plt.title('Place of Incident vs Reason')
plt.xticks(rotation=45)
plt.show()

# %%
# Police involvement vs. Reason
plt.figure(figsize=(10, 6))
sns.countplot(x='Police involvement', hue='Reason', data=df)
plt.title('Police Involvement vs Reason')
plt.show()

# %%
pivot_table = df.pivot_table(index='Month', columns='Year', aggfunc='size')

plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, cmap='Blues', annot=True, fmt="d")
plt.title('Incidents by Year and Month')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='Reason', y='Age', data=df, palette='muted')
plt.title('Age Distribution by Reason')
plt.show()

# %%
race_reason = df.groupby(['Race', 'Reason']).size().unstack()

race_reason.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')
plt.title('Incident Reason by Race')
plt.ylabel('Count of Incidents')
plt.xticks(rotation=45)
plt.show()

# %%
place_counts = df['Place of incident'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(place_counts, labels=place_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Set3'))
plt.title('Distribution of Incidents by Place')
plt.show()
